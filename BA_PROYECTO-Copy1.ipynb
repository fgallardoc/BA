# %% [markdown]
# PROYECTO BA

# %%
import pandas as pd
data_flights = pd.read_csv('flights.csv')
data = data_flights.copy()
# Out:
# C:\Users\feseg\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print ("Descripción estadistica")
data_flights.describe()
# Out:
# Descripción estadistica
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# min           1.000000e+00    1.000000e+00    -8.200000e+01  1.000000e+00
# 25%           9.170000e+02    9.210000e+02    -5.000000e+00  1.100000e+01
# 50%           1.325000e+03    1.330000e+03    -2.000000e+00  1.400000e+01
# 75%           1.730000e+03    1.740000e+03     7.000000e+00  1.900000e+01
# max           2.359000e+03    2.400000e+03     1.988000e+03  2.250000e+02
#
#          WHEELS_OFF  ...  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# count  5.730032e+06  ...       5.819079e+06  5.726566e+06   5.714008e+06
# mean   1.357171e+03  ...       1.493808e+03  1.476491e+03   4.407057e+00
# std    4.980094e+02  ...       5.071647e+02  5.263197e+02   3.927130e+01
# min    1.000000e+00  ...       1.000000e+00  1.000000e+00  -8.700000e+01
# 25%    9.350000e+02  ...       1.110000e+03  1.059000e+03  -1.300000e+01
# 50%    1.343000e+03  ...       1.520000e+03  1.512000e+03  -5.000000e+00
# 75%    1.754000e+03  ...       1.918000e+03  1.917000e+03   8.000000e+00
# max    2.400000e+03  ...       2.400000e+03  2.400000e+03   1.971000e+03
#
#            DIVERTED     CANCELLED  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# count  5.819079e+06  5.819079e+06      1.063439e+06    1.063439e+06
# mean   2.609863e-03  1.544643e-02      1.348057e+01    7.615387e-02
# std    5.102012e-02  1.233201e-01      2.800368e+01    2.143460e+00
# min    0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 25%    0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 50%    0.000000e+00  0.000000e+00      2.000000e+00    0.000000e+00
# 75%    0.000000e+00  0.000000e+00      1.800000e+01    0.000000e+00
# max    1.000000e+00  1.000000e+00      1.134000e+03    5.730000e+02
#
#        AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# count   1.063439e+06         1.063439e+06   1.063439e+06
# mean    1.896955e+01         2.347284e+01   2.915290e+00
# std     4.816164e+01         4.319702e+01   2.043334e+01
# min     0.000000e+00         0.000000e+00   0.000000e+00
# 25%     0.000000e+00         0.000000e+00   0.000000e+00
# 50%     2.000000e+00         3.000000e+00   0.000000e+00
# 75%     1.900000e+01         2.900000e+01   0.000000e+00
# max     1.971000e+03         1.331000e+03   1.211000e+03
#
# [8 rows x 26 columns]

# %%
#Cantidad de filas 
X = int(data.shape[0]/3)
# Creamos set mas pequeños para trabajar mas facil en una primera etapa de pogramación
#data_small= data[:50000]
#data_part_one = data[:X]
#data_part_two = data[X:2*X]
#data_part_three = data[2*X:]

print("Cantidad de filas set original = " + str(data_flights.shape[0]))
#print("Cantidad de filas set small = " + str(data_small.shape[0]))
#print("Cantidad de filas set part one = " + str(data_part_one.shape[0]))
#print("Cantidad de filas set part two = " + str(data_part_two.shape[0]))
#print("Cantidad de filas set part three = " + str(data_part_three.shape[0]))

data_small = data_flights[data_flights['MONTH'] == 1]
print("Cantidad de filas set small = " + str(data_small.shape[0]))
# Out:
# Cantidad de filas set original = 5819079
# Cantidad de filas set small = 469968

# %%
# concateno las variables YEAR,MONTH & DAY 
data = data_small.copy() #trabajamos por mientras con los datos del set pequeño 
data["FECHA"] = pd.to_datetime(data[["YEAR","MONTH", "DAY"]])
data.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_DELAY  \
# 0            ANC                 SEA                    5  ...          -22.0
# 1            LAX                 PBI                   10  ...           -9.0
# 2            SFO                 CLT                   20  ...            5.0
# 3            LAX                 MIA                   20  ...           -9.0
# 4            SEA                 ANC                   25  ...          -21.0
#
#    DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 0         0          0                  NaN               NaN             NaN
# 1         0          0                  NaN               NaN             NaN
# 2         0          0                  NaN               NaN             NaN
# 3         0          0                  NaN               NaN             NaN
# 4         0          0                  NaN               NaN             NaN
#
#    AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY      FECHA
# 0            NaN                  NaN            NaN 2015-01-01
# 1            NaN                  NaN            NaN 2015-01-01
# 2            NaN                  NaN            NaN 2015-01-01
# 3            NaN                  NaN            NaN 2015-01-01
# 4            NaN                  NaN            NaN 2015-01-01
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469968 entries, 0 to 469967
# Data columns (total 32 columns):
# YEAR                   469968 non-null int64
# MONTH                  469968 non-null int64
# DAY                    469968 non-null int64
# DAY_OF_WEEK            469968 non-null int64
# AIRLINE                469968 non-null object
# FLIGHT_NUMBER          469968 non-null int64
# TAIL_NUMBER            467186 non-null object
# ORIGIN_AIRPORT         469968 non-null object
# DESTINATION_AIRPORT    469968 non-null object
# SCHEDULED_DEPARTURE    469968 non-null int64
# DEPARTURE_TIME         458311 non-null float64
# DEPARTURE_DELAY        458311 non-null float64
# TAXI_OUT               458092 non-null float64
# WHEELS_OFF             458092 non-null float64
# SCHEDULED_TIME         469968 non-null float64
# ELAPSED_TIME           457013 non-null float64
# AIR_TIME               457013 non-null float64
# DISTANCE               469968 non-null int64
# WHEELS_ON              457697 non-null float64
# TAXI_IN                457697 non-null float64
# SCHEDULED_ARRIVAL      469968 non-null int64
# ARRIVAL_TIME           457697 non-null float64
# ARRIVAL_DELAY          457013 non-null float64
# DIVERTED               469968 non-null int64
# CANCELLED              469968 non-null int64
# CANCELLATION_REASON    11982 non-null object
# AIR_SYSTEM_DELAY       95951 non-null float64
# SECURITY_DELAY         95951 non-null float64
# AIRLINE_DELAY          95951 non-null float64
# LATE_AIRCRAFT_DELAY    95951 non-null float64
# WEATHER_DELAY          95951 non-null float64
# FECHA                  469968 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(16), int64(10), object(5)
# memory usage: 118.3+ MB

# %%
# porcentaje de registros de la variable que son missing values
print ("%MISSING VALUES")
#data_flights.isnull().sum()
import numpy as np
missing_values = []
for col in data.columns:
    i=data[col].isnull().sum()
    print ('{} = {}%'.format(col, i*100/data.shape[0]))
# Out:
# %MISSING VALUES
# YEAR = 0.0%
# MONTH = 0.0%
# DAY = 0.0%
# DAY_OF_WEEK = 0.0%
# AIRLINE = 0.0%
# FLIGHT_NUMBER = 0.0%
# TAIL_NUMBER = 0.5919551969495795%
# ORIGIN_AIRPORT = 0.0%
# DESTINATION_AIRPORT = 0.0%
# SCHEDULED_DEPARTURE = 0.0%
# DEPARTURE_TIME = 2.4803816430054813%
# DEPARTURE_DELAY = 2.4803816430054813%
# TAXI_OUT = 2.526980560378579%
# WHEELS_OFF = 2.526980560378579%
# SCHEDULED_TIME = 0.0%
# ELAPSED_TIME = 2.7565706601300515%
# AIR_TIME = 2.7565706601300515%
# DISTANCE = 0.0%
# WHEELS_ON = 2.611028836005856%
# TAXI_IN = 2.611028836005856%
# SCHEDULED_ARRIVAL = 0.0%
# ARRIVAL_TIME = 2.611028836005856%
# ARRIVAL_DELAY = 2.7565706601300515%
# DIVERTED = 0.0%
# CANCELLED = 0.0%
# CANCELLATION_REASON = 97.45046471249107%
# AIR_SYSTEM_DELAY = 79.58350355768903%
# SECURITY_DELAY = 79.58350355768903%
# AIRLINE_DELAY = 79.58350355768903%
# LATE_AIRCRAFT_DELAY = 79.58350355768903%
# WEATHER_DELAY = 79.58350355768903%
# FECHA = 0.0%

# %%
#print("Tipo de variable")
#data_flights.info()
#data_flights.columns.values
data_1=data.copy()
Variables_All = ['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
       'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
       'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
       'TAXI_OUT', 'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME',
       'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'TAXI_IN',
       'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED',
       'CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY',
       'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
       'WEATHER_DELAY', 'FECHA']
Variables_Borradas_1 =['AIR_SYSTEM_DELAY','SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
                       'WEATHER_DELAY','CANCELLATION_REASON'] # BORRADAS POR CANTIDAD DE MISSING VALUES
data_1.drop(Variables_Borradas_1, axis = 1, inplace = True)
data_1
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AS             98      N407AS
# 1       2015      1    1            4      AA           2336      N3KUAA
# 2       2015      1    1            4      US            840      N171US
# 3       2015      1    1            4      AA            258      N3HYAA
# 4       2015      1    1            4      AS            135      N527AS
# 5       2015      1    1            4      DL            806      N3730B
# 6       2015      1    1            4      NK            612      N635NK
# 7       2015      1    1            4      US           2013      N584UW
# 8       2015      1    1            4      AA           1112      N3LAAA
# 9       2015      1    1            4      DL           1173      N826DN
# 10      2015      1    1            4      DL           2336      N958DN
# 11      2015      1    1            4      AA           1674      N853AA
# 12      2015      1    1            4      DL           1434      N547US
# 13      2015      1    1            4      DL           2324      N3751B
# 14      2015      1    1            4      DL           2440      N651DL
# 15      2015      1    1            4      AS            108      N309AS
# 16      2015      1    1            4      DL           1560      N3743H
# 17      2015      1    1            4      UA           1197      N78448
# 18      2015      1    1            4      AS            122      N413AS
# 19      2015      1    1            4      DL           1670      N806DN
# 20      2015      1    1            4      NK            520      N525NK
# 21      2015      1    1            4      AA            371      N3GXAA
# 22      2015      1    1            4      NK            214      N632NK
# 23      2015      1    1            4      AA            115      N3CTAA
# 24      2015      1    1            4      DL           1450      N671DN
# 25      2015      1    1            4      UA           1545      N76517
# 26      2015      1    1            4      AS            130      N457AS
# 27      2015      1    1            4      NK            597      N528NK
# 28      2015      1    1            4      US            413      N571UW
# 29      2015      1    1            4      AA           2392      N3HRAA
# ...      ...    ...  ...          ...     ...            ...         ...
# 469938  2015      1   31            6      AA            384      N3GWAA
# 469939  2015      1   31            6      AA           2200      N3BGAA
# 469940  2015      1   31            6      B6            688      N643JB
# 469941  2015      1   31            6      US           2026      N524UW
# 469942  2015      1   31            6      US            675      N909AW
# 469943  2015      1   31            6      AA            272      N3ERAA
# 469944  2015      1   31            6      AA           1230      N3ARAA
# 469945  2015      1   31            6      AS            121      N763AS
# 469946  2015      1   31            6      B6            136      N729JB
# 469947  2015      1   31            6      DL           1088      N555NW
# 469948  2015      1   31            6      DL           1157      N722TW
# 469949  2015      1   31            6      AA           1062      N3EXAA
# 469950  2015      1   31            6      AA           1070      N3GXAA
# 469951  2015      1   31            6      AS            816      N581AS
# 469952  2015      1   31            6      B6            361      N632JB
# 469953  2015      1   31            6      B6            778      N594JB
# 469954  2015      1   31            6      B6           1853      N267JB
# 469955  2015      1   31            6      DL           1254      N137DL
# 469956  2015      1   31            6      F9            712      N932FR
# 469957  2015      1   31            6      UA           1557      N68823
# 469958  2015      1   31            6      UA           1604      N66825
# 469959  2015      1   31            6      B6             98      N535JB
# 469960  2015      1   31            6      US            889      N656AW
# 469961  2015      1   31            6      B6            802      N590JB
# 469962  2015      1   31            6      B6            745      N627JB
# 469963  2015      1   31            6      B6            839      N658JB
# 469964  2015      1   31            6      DL           1887      N855NW
# 469965  2015      1   31            6      F9            300      N218FR
# 469966  2015      1   31            6      F9            422      N954FR
# 469967  2015      1   31            6      UA           1104      N73251
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  AIR_TIME  \
# 0                 ANC                 SEA                    5  ...     169.0
# 1                 LAX                 PBI                   10  ...     263.0
# 2                 SFO                 CLT                   20  ...     266.0
# 3                 LAX                 MIA                   20  ...     258.0
# 4                 SEA                 ANC                   25  ...     199.0
# 5                 SFO                 MSP                   25  ...     206.0
# 6                 LAS                 MSP                   25  ...     154.0
# 7                 LAX                 CLT                   30  ...     228.0
# 8                 SFO                 DFW                   30  ...     173.0
# 9                 LAS                 ATL                   30  ...     186.0
# 10                DEN                 ATL                   30  ...     133.0
# 11                LAS                 MIA                   35  ...     238.0
# 12                LAX                 MSP                   35  ...     188.0
# 13                SLC                 ATL                   40  ...     176.0
# 14                SEA                 MSP                   40  ...     166.0
# 15                ANC                 SEA                   45  ...     173.0
# 16                ANC                 SEA                   45  ...     171.0
# 17                SFO                 IAH                   48  ...     199.0
# 18                ANC                 PDX                   50  ...     187.0
# 19                PDX                 MSP                   50  ...     171.0
# 20                LAS                 MCI                   55  ...     128.0
# 21                SEA                 MIA                  100  ...     311.0
# 22                LAS                 DFW                  103  ...     128.0
# 23                LAX                 MIA                  105  ...     255.0
# 24                LAS                 MSP                  105  ...     150.0
# 25                LAX                 IAH                  115  ...     156.0
# 26                FAI                 SEA                  115  ...     186.0
# 27                MSP                 FLL                  115  ...     166.0
# 28                LAS                 CLT                  120  ...     205.0
# 29                DEN                 MIA                  120  ...     188.0
# ...               ...                 ...                  ...  ...       ...
# 469938            LAX                 MIA                 2345  ...     263.0
# 469939            MIA                 MCO                 2349  ...      36.0
# 469940            LAX                 BOS                 2349  ...     299.0
# 469941            PHX                 PHL                 2350  ...     233.0
# 469942            HNL                 PHX                 2350  ...       NaN
# 469943            SFO                 MIA                 2350  ...     288.0
# 469944            SEA                 DFW                 2350  ...     181.0
# 469945            SEA                 ANC                 2350  ...     189.0
# 469946            PHX                 JFK                 2350  ...     242.0
# 469947            ANC                 MSP                 2350  ...     285.0
# 469948            HNL                 SFO                 2350  ...     257.0
# 469949            LAX                 ORD                 2354  ...     208.0
# 469950            SEA                 MIA                 2355  ...     299.0
# 469951            LIH                 SEA                 2355  ...     277.0
# 469952            BOS                 SJU                 2355  ...     189.0
# 469953            LAS                 BOS                 2355  ...     260.0
# 469954            FLL                 SJU                 2355  ...     120.0
# 469955            LAX                 ATL                 2355  ...     221.0
# 469956            DEN                 RSW                 2355  ...     181.0
# 469957            LAX                 EWR                 2356  ...     286.0
# 469958            HNL                 SFO                 2356  ...     262.0
# 469959            DEN                 JFK                 2357  ...     182.0
# 469960            PHX                 MSP                 2359  ...     159.0
# 469961            SLC                 MCO                 2359  ...     214.0
# 469962            JFK                 PSE                 2359  ...     182.0
# 469963            JFK                 BQN                 2359  ...     179.0
# 469964            SEA                 DTW                 2359  ...     209.0
# 469965            DEN                 TPA                 2359  ...     168.0
# 469966            DEN                 ATL                 2359  ...     141.0
# 469967            ANC                 DEN                 2359  ...     282.0
#
#         DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# 0           1448      404.0      4.0                430         408.0
# 1           2330      737.0      4.0                750         741.0
# 2           2296      800.0     11.0                806         811.0
# 3           2342      748.0      8.0                805         756.0
# 4           1448      254.0      5.0                320         259.0
# 5           1589      604.0      6.0                602         610.0
# 6           1299      504.0      5.0                526         509.0
# 7           2125      745.0      8.0                803         753.0
# 8           1464      529.0      3.0                545         532.0
# 9           1747      651.0      5.0                711         656.0
# 10          1199      449.0      4.0                523         453.0
# 11          2174      746.0      7.0                803         753.0
# 12          1535      601.0      4.0                609         605.0
# 13          1590      548.0      5.0                615         553.0
# 14          1399      553.0      4.0                549         557.0
# 15          1448      451.0      4.0                509         455.0
# 16          1448      447.0      4.0                515         451.0
# 17          1635      612.0      7.0                626         619.0
# 18          1542      504.0      3.0                525         507.0
# 19          1426      545.0      6.0                603         551.0
# 20          1139      539.0      4.0                537         543.0
# 21          2724      933.0      6.0                938         939.0
# 22          1055      523.0      6.0                530         529.0
# 23          2342      832.0      7.0                851         839.0
# 24          1299      543.0      2.0                608         545.0
# 25          1379      559.0      8.0                618         607.0
# 26          1533      538.0      7.0                548         545.0
# 27          1487      527.0     40.0                542         607.0
# 28          1916      747.0      7.0                825         754.0
# 29          1709      701.0      8.0                707         709.0
# ...          ...        ...      ...                ...           ...
# 469938      2342      718.0      9.0                729         727.0
# 469939       192       35.0      4.0                 49          39.0
# 469940      2611      827.0     12.0                809         839.0
# 469941      2075      556.0      7.0                603         603.0
# 469942      2917        NaN      NaN                843           NaN
# 469943      2585      750.0      3.0                800         753.0
# 469944      1660      514.0      5.0                527         519.0
# 469945      1448      354.0      4.0                240         358.0
# 469946      2153      608.0      5.0                617         613.0
# 469947      2519      803.0      9.0                808         812.0
# 469948      2398      620.0      7.0                705         627.0
# 469949      1744      539.0     14.0                550         553.0
# 469950      2724      801.0      7.0                826         808.0
# 469951      2701      727.0      7.0                736         734.0
# 469952      1674      415.0      4.0                451         419.0
# 469953      2381      812.0      7.0                745         819.0
# 469954      1046      305.0      4.0                319         309.0
# 469955      1947      644.0      7.0                700         651.0
# 469956      1607      528.0      6.0                521         534.0
# 469957      2454      800.0     11.0                811         811.0
# 469958      2398      639.0      7.0                710         646.0
# 469959      1626      629.0      7.0                528         636.0
# 469960      1276      340.0      8.0                359         348.0
# 469961      1931      552.0      4.0                613         556.0
# 469962      1617      414.0      4.0                446         418.0
# 469963      1576      416.0      3.0                440         419.0
# 469964      1927      644.0     14.0                711         658.0
# 469965      1506      525.0      9.0                511         534.0
# 469966      1199      500.0     10.0                441         510.0
# 469967      2405      703.0      7.0                708         710.0
#
#         ARRIVAL_DELAY  DIVERTED  CANCELLED      FECHA
# 0               -22.0         0          0 2015-01-01
# 1                -9.0         0          0 2015-01-01
# 2                 5.0         0          0 2015-01-01
# 3                -9.0         0          0 2015-01-01
# 4               -21.0         0          0 2015-01-01
# 5                 8.0         0          0 2015-01-01
# 6               -17.0         0          0 2015-01-01
# 7               -10.0         0          0 2015-01-01
# 8               -13.0         0          0 2015-01-01
# 9               -15.0         0          0 2015-01-01
# 10              -30.0         0          0 2015-01-01
# 11              -10.0         0          0 2015-01-01
# 12               -4.0         0          0 2015-01-01
# 13              -22.0         0          0 2015-01-01
# 14                8.0         0          0 2015-01-01
# 15              -14.0         0          0 2015-01-01
# 16              -24.0         0          0 2015-01-01
# 17               -7.0         0          0 2015-01-01
# 18              -18.0         0          0 2015-01-01
# 19              -12.0         0          0 2015-01-01
# 20                6.0         0          0 2015-01-01
# 21                1.0         0          0 2015-01-01
# 22               -1.0         0          0 2015-01-01
# 23              -12.0         0          0 2015-01-01
# 24              -23.0         0          0 2015-01-01
# 25              -11.0         0          0 2015-01-01
# 26               -3.0         0          0 2015-01-01
# 27               25.0         0          0 2015-01-01
# 28              -31.0         0          0 2015-01-01
# 29                2.0         0          0 2015-01-01
# ...               ...       ...        ...        ...
# 469938           -2.0         0          0 2015-01-31
# 469939          -10.0         0          0 2015-01-31
# 469940           30.0         0          0 2015-01-31
# 469941            0.0         0          0 2015-01-31
# 469942            NaN         1          0 2015-01-31
# 469943           -7.0         0          0 2015-01-31
# 469944           -8.0         0          0 2015-01-31
# 469945           78.0         0          0 2015-01-31
# 469946           -4.0         0          0 2015-01-31
# 469947            4.0         0          0 2015-01-31
# 469948          -38.0         0          0 2015-01-31
# 469949            3.0         0          0 2015-01-31
# 469950          -18.0         0          0 2015-01-31
# 469951           -2.0         0          0 2015-01-31
# 469952          -32.0         0          0 2015-01-31
# 469953           34.0         0          0 2015-01-31
# 469954          -10.0         0          0 2015-01-31
# 469955           -9.0         0          0 2015-01-31
# 469956           13.0         0          0 2015-01-31
# 469957            0.0         0          0 2015-01-31
# 469958          -24.0         0          0 2015-01-31
# 469959           68.0         0          0 2015-01-31
# 469960          -11.0         0          0 2015-01-31
# 469961          -17.0         0          0 2015-01-31
# 469962          -28.0         0          0 2015-01-31
# 469963          -21.0         0          0 2015-01-31
# 469964          -13.0         0          0 2015-01-31
# 469965           23.0         0          0 2015-01-31
# 469966           29.0         0          0 2015-01-31
# 469967            2.0         0          0 2015-01-31
#
# [469968 rows x 26 columns]

# %%
# esta wea la encontre en internet 
import datetime, warnings, scipy 
import pandas as pd
import numpy as np

# %%
# Se aplica la funcion de la linea anterior a las siguienes variables 
data_1['SCHEDULED_DEPARTURE'] = create_flight_time(data_1, 'SCHEDULED_DEPARTURE')
data_1['SCHEDULED_ARRIVAL'] = data_1['SCHEDULED_ARRIVAL'].apply(format_heure)
data_1['ARRIVAL_TIME'] = data_1['ARRIVAL_TIME'].apply(format_heure)
data_1['DEPARTURE_TIME'] = data_1['DEPARTURE_TIME'].apply(format_heure)
data_1.loc[:5, ['SCHEDULED_DEPARTURE', 'SCHEDULED_ARRIVAL', 'DEPARTURE_TIME',
             'ARRIVAL_TIME', 'DEPARTURE_DELAY', 'ARRIVAL_DELAY']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-8e2c0e58eded> in <module>
#       1 # Se aplica la funcion de la linea anterior a las siguienes variables
# ----> 2 data_1['SCHEDULED_DEPARTURE'] = create_flight_time(data_1, 'SCHEDULED_DEPARTURE')
#       3 data_1['SCHEDULED_ARRIVAL'] = data_1['SCHEDULED_ARRIVAL'].apply(format_heure)
#       4 data_1['ARRIVAL_TIME'] = data_1['ARRIVAL_TIME'].apply(format_heure)
#       5 data_1['DEPARTURE_TIME'] = data_1['DEPARTURE_TIME'].apply(format_heure)
#
# <ipython-input-45-08b3bcedff89> in create_flight_time(df, col)
#      23         if pd.isnull(cols[1]):
#      24             liste.append(np.nan)
# ---> 25         elif float(cols[1]) == 2400:
#      26             cols[0] += datetime.timedelta(days=1)
#      27             cols[1] = datetime.time(0,0)
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'
